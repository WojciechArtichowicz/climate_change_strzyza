# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#main_dir = "C:/Users/wojci/Downloads/CLIMATE_DATA" #windows machine
main_dir = "/home/wojciech/Pobrane/CLIMATE_DATA" # Linux machine
prepared_dir = "PREPARED"


climate_directory = "CLIMATE"
df_kmt = pd.read_csv(os.path.join(main_dir, climate_directory, prepared_dir,"kmt.csv"),index_col=0)
df_kmd = pd.read_csv(os.path.join(main_dir, climate_directory, prepared_dir,"kmd.csv"),index_col=0)

synoptic_directory = "SYNOPTIC"
df_smt = pd.read_csv(os.path.join(main_dir, synoptic_directory, prepared_dir,"smt.csv"),index_col=0)
df_smd = pd.read_csv(os.path.join(main_dir, synoptic_directory, prepared_dir,"smd.csv"),index_col=0)

precipitation_directory = "PRECIPITATION"
df_om = pd.read_csv(os.path.join(main_dir, precipitation_directory, prepared_dir,"om.csv"),index_col=0)

# %%
df_kmt
# Out:
#       Kod stacji Nazwa stacji   Rok  Miesiąc  \
# 0      249180010     PSZCZYNA  1971        1
# 1      249180010     PSZCZYNA  1971        2
# 2      249180010     PSZCZYNA  1971        3
# 3      249180010     PSZCZYNA  1971        4
# 4      249180010     PSZCZYNA  1971        5
# ...          ...          ...   ...      ...
# 1896   254220090       OLECKO  2004        8
# 1897   254220090       OLECKO  2004        9
# 1898   254220090       OLECKO  2004       10
# 1899   254220090       OLECKO  2004       11
# 1900   254220090       OLECKO  2004       12
#
#       Średnia miesięczna temperatura [°C]  Status pomiaru TEMP  \
# 0                                    -3.2                  NaN
# 1                                     0.5                  NaN
# 2                                     0.6                  NaN
# 3                                     9.1                  NaN
# 4                                    16.2                  NaN
# ...

# %%
df_kmd
# Out:
#       Kod stacji Nazwa stacji   Rok  Miesiąc  \
# 0      249180010     PSZCZYNA  1971        1
# 1      249180010     PSZCZYNA  1971        2
# 2      249180010     PSZCZYNA  1971        3
# 3      249180010     PSZCZYNA  1971        4
# 4      249180010     PSZCZYNA  1971        5
# ...          ...          ...   ...      ...
# 1860   254220090       OLECKO  2014        8
# 1861   254220090       OLECKO  2014        9
# 1862   254220090       OLECKO  2014       10
# 1863   254220090       OLECKO  2014       11
# 1864   254220090       OLECKO  2014       12
#
#       Absolutna temperatura maksymalna [°C]  Status pomiaru TMAX  \
# 0                                      13.9                  NaN
# 1                                      12.1                  NaN
# 2                                      20.8                  NaN
# 3                                      22.4                  NaN
# 4                                      28.7                  NaN
# ...

# %%
df_smd
# Out:
#       Kod stacji   Nazwa stacji   Rok  Miesiąc  \
# 0      349190600  BIELSKO-BIAŁA  2004        1
# 1      349190600  BIELSKO-BIAŁA  2004        2
# 2      349190600  BIELSKO-BIAŁA  2004        3
# 3      349190600  BIELSKO-BIAŁA  2004        4
# 4      349190600  BIELSKO-BIAŁA  2004        5
# ...          ...            ...   ...      ...
# 3635   354220195        SUWAŁKI  1995        8
# 3636   354220195        SUWAŁKI  1995        9
# 3637   354220195        SUWAŁKI  1995       10
# 3638   354220195        SUWAŁKI  1995       11
# 3639   354220195        SUWAŁKI  1995       12
#
#       Absolutna temperatura maksymalna [°C]  Status pomiaru TMAX  \
# 0                                       5.7                  NaN
# 1                                      13.8                  NaN
# 2                                      21.0                  NaN
# 3                                      20.3                  NaN
# 4                                      23.5                  NaN
# ...

# %%
df_smt
# Out:
#      Kod stacji   Nazwa stacji   Rok  Miesiąc  \
# 0     349190600  BIELSKO-BIAŁA  1991        1
# 1     349190600  BIELSKO-BIAŁA  1991        2
# 2     349190600  BIELSKO-BIAŁA  1991        3
# 3     349190600  BIELSKO-BIAŁA  1991        4
# 4     349190600  BIELSKO-BIAŁA  1991        5
# ..          ...            ...   ...      ...
# 691   354220195        SUWAŁKI  2008        8
# 692   354220195        SUWAŁKI  2008        9
# 693   354220195        SUWAŁKI  2008       10
# 694   354220195        SUWAŁKI  2008       11
# 695   354220195        SUWAŁKI  2008       12
#
#      Średnie miesięczne zachmurzenie ogólne [oktanty]  Status pomiaru NOS  \
# 0                                                 4.7                 NaN
# 1                                                 4.9                 NaN
# 2                                                 5.4                 NaN
# 3                                                 5.3                 NaN
# ...

# %%
df_om
# Out:
#        Kod stacji Nazwa stacji   Rok  Miesiąc  Miesięczna suma opadów [mm]  \
# 0       249180020   WARSZOWICE  2019        1                         97.7
# 1       249180020   WARSZOWICE  2019        2                         34.0
# 2       249180020   WARSZOWICE  2019        3                         39.8
# 3       249180020   WARSZOWICE  2019        4                         51.1
# 4       249180020   WARSZOWICE  2019        5                        124.0
# ...           ...          ...   ...      ...                          ...
# 60125   254239999      SMOLANY  1965        8                         61.0
# 60126   254239999      SMOLANY  1965        9                         38.6
# 60127   254239999      SMOLANY  1965       10                         17.7
# 60128   254239999      SMOLANY  1965       11                         42.3
# 60129   254239999      SMOLANY  1965       12                         26.6
#
# ...

# %%
station_gd_r = 'GDAŃSK-RĘBIECHOWO'
code_gd_r = 254180090

station_gd_sw = 'GDAŃSK-ŚWIBNO'
code_gd_sw = 254180110

station_gdy = 'GDYNIA' 
code_gdy = 254180060

# %%
df_gd_r =  df_kmd.loc[df_kmd["Kod stacji"]==code_gd_r]
df_gd_r.head()
# Out:
#      Kod stacji       Nazwa stacji   Rok  Miesiąc  \
# 837   254180090  GDAŃSK-RĘBIECHOWO  2017        1
# 838   254180090  GDAŃSK-RĘBIECHOWO  2017        2
# 839   254180090  GDAŃSK-RĘBIECHOWO  2017        3
# 840   254180090  GDAŃSK-RĘBIECHOWO  2017        4
# 841   254180090  GDAŃSK-RĘBIECHOWO  2017        5
#
#      Absolutna temperatura maksymalna [°C]  Status pomiaru TMAX  \
# 837                                    4.6                  NaN
# 838                                   10.4                  NaN
# 839                                   19.2                  NaN
# 840                                   22.8                  NaN
# 841                                   27.3                  NaN
#
#      Średnia temperatura maksymalna [°C]  Status pomiaru TMXS  \
# 837                                  0.1                  NaN
# 838                                  2.0                  NaN
# 839                                  8.2                  NaN
# ...

# %%
df_gd_r[["Kod stacji","Rok",'Miesieczna suma opadów  [mm]']].groupby(["Kod stacji","Rok"]).sum()
# Out:
#                  Miesieczna suma opadów  [mm]
# Kod stacji Rok
# 254180090  1991                         497.7
#            1992                         489.4
#            1993                         515.7
#            2000                         573.6
#            2001                         806.7
#            2002                         669.3
#            2003                         525.5
#            2004                         736.4
#            2005                         492.0
#            2006                         610.0
#            2007                         753.3
#            2008                         627.1
#            2009                         602.7
#            2010                         875.0
#            2011                         441.3
#            2012                         641.8
#            2013                         696.0
#            2014                         450.0
#            2015                         521.8
# ...

# %%
df_gd_r1 = df_om.loc[df_om["Kod stacji"]==code_gd_r]
df_gd_r1.head()
# Out:
#        Kod stacji       Nazwa stacji   Rok  Miesiąc  \
# 66649   254180090  GDAŃSK-RĘBIECHOWO  1981        1
# 66650   254180090  GDAŃSK-RĘBIECHOWO  1981        2
# 66651   254180090  GDAŃSK-RĘBIECHOWO  1981        3
# 66652   254180090  GDAŃSK-RĘBIECHOWO  1981        4
# 66653   254180090  GDAŃSK-RĘBIECHOWO  1981        5
#
#        Miesięczna suma opadów [mm]  Status pomiaru SUMM  \
# 66649                         32.0                  NaN
# 66650                         30.5                  NaN
# 66651                         31.9                  NaN
# 66652                         25.1                  NaN
# 66653                         22.7                  NaN
#
#        Liczba dni z opadem śniegu  Status pomiaru LDS  Opad maksymalny [mm]  \
# 66649                           0                 8.0                  10.6
# 66650                           0                 8.0                   7.1
# 66651                           0                 8.0                   4.6
# ...

# %%
df_gd_r1[["Kod stacji","Rok",'Miesięczna suma opadów [mm]']].groupby(["Kod stacji","Rok"]).sum()
# Out:
#                  Miesięczna suma opadów [mm]
# Kod stacji Rok
# 254180090  1975                        428.4
#            1976                        460.9
#            1977                        524.4
#            1978                        645.7
#            1979                        461.8
#            1980                        758.7
#            1981                        663.5
#            1982                        360.9
#            1983                        613.3
#            1984                        517.7
#            1988                        444.7
#            1989                        399.0
#            1990                        641.8
#            1996                        625.1
#            1997                        615.2

# %%
set(df_gd_r["Rok"].unique()) & set(df_gd_r1["Rok"].unique())
# Out:
# set()

# %%
df_gd_r2 = df_smd.loc[df_smd["Kod stacji"]==code_gd_r]
df_gd_r2.head()
# Out:
# Empty DataFrame
# ...

# %%
df_gd_r2[["Kod stacji","Rok",'Miesięczna suma opadów [mm]']].groupby(["Kod stacji","Rok"]).sum()
# Out:
# Empty DataFrame
# Columns: [Miesięczna suma opadów [mm]]
# Index: []

# %%
df_smd["Nazwa stacji"].unique()
# Out:
# array(['BIELSKO-BIAŁA', 'ZAKOPANE', 'KASPROWY WIERCH', 'NOWY SĄCZ',
#        'KROSNO', 'LESKO', 'JELENIA GÓRA', 'ŚNIEŻKA', 'KŁODZKO', 'OPOLE',
#        'RACIBÓRZ', 'CZĘSTOCHOWA', 'KATOWICE', 'KRAKÓW-BALICE',
#        'KIELCE-SUKÓW', 'TARNÓW', 'SANDOMIERZ', 'RZESZÓW-JASIONKA',
#        'ZIELONA GÓRA', 'LEGNICA', 'LESZNO', 'WROCŁAW', 'KALISZ', 'WIELUŃ',
#        'ŁÓDŹ', 'SULEJÓW', 'KOZIENICE', 'LUBLIN-RADAWIEC', 'WŁODAWA',
#        'SŁUBICE', 'GORZÓW WIELKOPOLSKI', 'POZNAŃ', 'KOŁO', 'PŁOCK',
#        'WARSZAWA', 'SIEDLCE', 'TERESPOL', 'ŚWINOUJŚCIE', 'SZCZECIN',
#        'RESKO-SMÓLSKO', 'PIŁA', 'CHOJNICE', 'TORUŃ', 'MŁAWA', 'OLSZTYN',
#        'MIKOŁAJKI', 'BIAŁYSTOK', 'KOŁOBRZEG', 'KOSZALIN', 'USTKA', 'ŁEBA',
#        'LĘBORK', 'HEL', 'GDAŃSK-PORT PÓŁNOCNY', 'ELBLĄG-MILEJEWO',
#        'KĘTRZYN', 'SUWAŁKI', 'HALA GĄSIENICOWA', 'KATOWICE-MUCHOWIEC',
#        'ZAMOŚĆ', 'WROCŁAW-STRACHOWICE', 'ŁÓDŹ-LUBLINEK', 'POZNAŃ-ŁAWICA',
# ...
